# %%
import logging
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

logging.basicConfig(
    format='%(asctime)s %(levelname)s:%(message)s',
    level=logging.INFO)

class Crawler:

    def __init__(self, urls=[]):
        self.visited_urls = []
        self.urls_to_visit = urls
        self.linksearch = {
            "word(count)":[],
            "URL":[]
        }
        
    def download_url(self, url):
        return requests.get(url).text

    def get_linked_urls(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        for link in soup.find_all('a'):
            path = link.get('href')
            if path and path.startswith('/'):
                path = urljoin(url, path)
            yield path

    def add_url_to_visit(self, url):
        if url not in self.visited_urls and url not in self.urls_to_visit:
            if '#' not in url or '?' not in url or 'None' not in url:
                self.urls_to_visit.append(url)

    def crawl(self, url):
        html = self.download_url(url)
        self.search_title(html,url)
        self.search(html,url)
        for url in self.get_linked_urls(url, html):
            self.add_url_to_visit(url)


    def run(self):
#         i = 0
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
#             logging.info(f'Crawling: {url}')
            try:
#                 if i == 20:                    
#                     break
                self.crawl(url)
#                 i += 1
            except Exception:
                pass
#                 logging.exception(f'Failed to crawl: {url}')
            finally:
                self.visited_urls.append(url)

    def search(self,html,url):
        searched_word = ["Sono Bisque Doll wa Koi wo Suru","anime","thailand"]
        soup = BeautifulSoup(html, 'html.parser')
        results = soup.body.find_all(string=re.compile('.*{0}.*'.format(searched_word[0])), recursive=True)
        print('Found the word "{0}" {1} times in {2}\n'.format(searched_word[0], len(results),url))
        results1 = soup.body.find_all(string=re.compile('.*{0}.*'.format(searched_word[1])), recursive=True)
        print('Found the word "{0}" {1} times in {2}\n'.format(searched_word[1], len(results1),url))
        results2 = soup.body.find_all(string=re.compile('.*{0}.*'.format(searched_word[2])), recursive=True)
        print('Found the word "{0}" {1} times in {2}\n'.format(searched_word[2], len(results2),url))
#         print(results)
    def search_title(self,html,url):
        searched_word = ["Sono Bisque Doll wa Koi wo Suru","anime","thailand"]
        soup = BeautifulSoup(html, 'html.parser')
        results = soup.title.find_all(string=re.compile('.*{0}.*'.format(searched_word)), recursive=True)
        if  len(results) >= 1:
            self.linksearch["word(count)"].append(str(len(results)))
            self.linksearch["URL"].append(url)
#         df = pd.DataFrame(self.linksearch)
#         print(self.linksearch)
#         print(df)

        


if __name__ == '__main__':
    Crawler(urls=['https://myanimelist.net/anime/genre/48/Work_Life','https://anime-kimuchi.com/','https://anime-fast.online/']).run()
# Out:
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://myanimelist.net/anime/genre/48/Work_Life
#
# Found the word "anime" 11 times in https://myanimelist.net/anime/genre/48/Work_Life
#
# Found the word "thailand" 0 times in https://myanimelist.net/anime/genre/48/Work_Life
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://anime-kimuchi.com/
#
# Found the word "anime" 10 times in https://anime-kimuchi.com/
#
# Found the word "thailand" 0 times in https://anime-kimuchi.com/
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 1 times in https://anime-fast.online/
#
# Found the word "anime" 0 times in https://anime-fast.online/
#
# Found the word "thailand" 0 times in https://anime-fast.online/
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://mxj.myanimelist.net/
#
# Found the word "anime" 10 times in https://mxj.myanimelist.net/
#
# Found the word "thailand" 0 times in https://mxj.myanimelist.net/
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://myanimelist.net/membership?_location=mal_h_u
#
# Found the word "anime" 5 times in https://myanimelist.net/membership?_location=mal_h_u
#
# Found the word "thailand" 0 times in https://myanimelist.net/membership?_location=mal_h_u
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://myanimelist.net/login.php?from=%2Fanime%2Fgenre%2F48%2FWork_Life
#
# Found the word "anime" 6 times in https://myanimelist.net/login.php?from=%2Fanime%2Fgenre%2F48%2FWork_Life
#
# Found the word "thailand" 0 times in https://myanimelist.net/login.php?from=%2Fanime%2Fgenre%2F48%2FWork_Life
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://myanimelist.net/register.php?from=%2Fanime%2Fgenre%2F48%2FWork_Life
#
# Found the word "anime" 3 times in https://myanimelist.net/register.php?from=%2Fanime%2Fgenre%2F48%2FWork_Life
#
# Found the word "thailand" 0 times in https://myanimelist.net/register.php?from=%2Fanime%2Fgenre%2F48%2FWork_Life
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 1 times in https://myanimelist.net/
#
# Found the word "anime" 17 times in https://myanimelist.net/
#
# Found the word "thailand" 0 times in https://myanimelist.net/
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://anime-kimuchi.com
#
# Found the word "anime" 10 times in https://anime-kimuchi.com
#
# Found the word "thailand" 0 times in https://anime-kimuchi.com
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://anime-kimuchi.com/category/%e0%b8%ad%e0%b8%99%e0%b8%b4%e0%b9%80%e0%b8%a1%e0%b8%b0%e0%b8%9e%e0%b8%b2%e0%b8%81%e0%b8%a2%e0%b9%8c%e0%b9%84%e0%b8%97%e0%b8%a2/
#
# Found the word "anime" 8 times in https://anime-kimuchi.com/category/%e0%b8%ad%e0%b8%99%e0%b8%b4%e0%b9%80%e0%b8%a1%e0%b8%b0%e0%b8%9e%e0%b8%b2%e0%b8%81%e0%b8%a2%e0%b9%8c%e0%b9%84%e0%b8%97%e0%b8%a2/
#
# Found the word "thailand" 0 times in https://anime-kimuchi.com/category/%e0%b8%ad%e0%b8%99%e0%b8%b4%e0%b9%80%e0%b8%a1%e0%b8%b0%e0%b8%9e%e0%b8%b2%e0%b8%81%e0%b8%a2%e0%b9%8c%e0%b9%84%e0%b8%97%e0%b8%a2/
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://anime-kimuchi.com/category/%e0%b8%ad%e0%b8%99%e0%b8%b4%e0%b9%80%e0%b8%a1%e0%b8%b0%e0%b8%8b%e0%b8%b1%e0%b8%9a%e0%b9%84%e0%b8%97%e0%b8%a2/
#
# Found the word "anime" 7 times in https://anime-kimuchi.com/category/%e0%b8%ad%e0%b8%99%e0%b8%b4%e0%b9%80%e0%b8%a1%e0%b8%b0%e0%b8%8b%e0%b8%b1%e0%b8%9a%e0%b9%84%e0%b8%97%e0%b8%a2/
#
# Found the word "thailand" 0 times in https://anime-kimuchi.com/category/%e0%b8%ad%e0%b8%99%e0%b8%b4%e0%b9%80%e0%b8%a1%e0%b8%b0%e0%
times in https://anime-kimuchi.com/category/%e0%b8%ad%e0%b8%99%e0%b8%b4%e0%b9%80%e0%b8%a1%e0%b8%b0%e0%b9%80%e0%b8%81%e0%b8%a1%e0%b8%ad%e0%b8%ad%e0%b8%99%e0%b9%84%e0%b8%a5%e0%b8%99%e0%b9%8c/
#
# Found the word "thailand" 0 times in https://anime-kimuchi.com/category/%e0%b8%ad%e0%b8%99%e0%b8%b4%e0%b9%80%e0%b8%a1%e0%b8%b0%e0%b9%80%e0%b8%81%e0%b8%a1%e0%b8%ad%e0%b8%ad%e0%b8%99%e0%b9%84%e0%b8%a5%e0%b8%99%e0%b9%8c/
#
# Found the word "Sono Bisque Doll wa Koi wo Suru" 0 times in https://anime-kimuchi.com/category/%e0%b8%81%e0%b8%b2%e0%b8%a3%e0%b9%8c%e0%b8%95%e0%b8%b9%e0%b8%99%e0%b8%9c%e0%b8%88%e0%b8%8d%e0%b8%a0%e0%b8%b1%e0%b8%a2/
#
# Found the word "anime" 7 times in https://anime-kimuchi.com/category/%e0%b8%81%e0%b8%b2%e0%b8%a3%e0%b9%8c%e0%b8%95%e0%b8%b9%e0%b8%99%e0%b8%9c%e0%b8%88%e0%b8%8d%e0%b8%a0%e0%b8%b1%e0%b8%a2/
#
# Found the word "thailand" 0 times in https://anime-kimuchi.com/category/%e0%b8%81%e0%b8%b2%e0%b8%a3%e0%b9%8c%e0%b8%95%e0%b8%b9%e0%b8%99%e0%b8%9c%e0%b8%88%e0%b8%8d%e0%b8%a0%e0%b8%b1%e0%b8%a2/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9508/4276890301.py in <module>
#      85
#      86 if __name__ == '__main__':
# ---> 87     Crawler(urls=['https://myanimelist.net/anime/genre/48/Work_Life','https://anime-kimuchi.com/','https://anime-fast.online/']).run()
#      88
#
# ~\AppData\Local\Temp/ipykernel_9508/4276890301.py in run(self)
#      52 #                 if i == 20:
#      53 #                     break
# ---> 54                 self.crawl(url)
#      55 #                 i += 1
#      56             except Exception:
#
# ~\AppData\Local\Temp/ipykernel_9508/4276890301.py in crawl(self, url)
#      37
#      38     def crawl(self, url):
# ---> 39         html = self.download_url(url)
#      40         self.search_title(html,url)
#      41         self.search(html,url)
#
# ~\AppData\Local\Temp/ipykernel_9508/4276890301.py in download_url(self, url)
#      21
#      22     def download_url(self, url):
# ---> 23         return requests.get(url).text
#      24
#      25     def get_linked_urls(self, url, html):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     685
#     686         if not stream:
# --> 687             r.content
#     688
#     689         return r
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py in content(self)
#     836                 self._content = None
#     837             else:
# --> 838                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     839
#     840         self._content_consumed = True
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# ~\AppData\Local\Programs\Python\Python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
data = {'word(count)': ['1'], 'URL': ['https://www.thsport.com/sitemap.xml']}
df = pd.DataFrame(data)
print(df)
